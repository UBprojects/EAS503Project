# %%
import plotter

# %%
plotter.plot_department_pay(limit=10)

# %%
plotter.plot_designation_pay(limit=10)

# %%
plotter.plot_department_public_private_pay(limit=10)

# %%
plotter.plot_department_part_full_time(limit=10)
